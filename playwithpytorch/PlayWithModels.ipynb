# %%
# imports
import matplotlib.pyplot as plt
import numpy as np
from os import path
import os

import torch
import torchvision
import torchvision.transforms as transforms

import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from CustomDataSet import CustomAnimal10DataSet
from PIL import Image, ImageFile

# %%
# transforms
transform = transforms.Compose(
    [transforms.ToTensor(),
    transforms.Normalize((0.5,), (0.5,))])

diff_transform = transforms.Compose([
        transforms.RandomResizedCrop(224),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
        transforms.Normalize((0.5,), (0.5,))])

# %%
path_to_dataset = r"C:\Users\HFD347\develp\Datasets\Animals-10"
test_dataset = CustomAnimal10DataSet(path_to_dataset, diff_transform)

# %%
def matplotlib_imshow(img, one_channel=False):
    if one_channel:
        img = img.mean(dim=0)
    img = img / 2 + 0.5     # unnormalize
    npimg = img.numpy()
    if one_channel:
        plt.imshow(npimg, cmap="Greys")
    else:
        plt.imshow(np.transpose(npimg, (1, 2, 0)))

# %%
imgs = [test_dataset[idx][0] for idx in range(1, 4)]
out = torchvision.utils.make_grid(imgs)
matplotlib_imshow(out)

# %%
im[0][0].shape
# Out:
# torch.Size([3, 224, 224])

# %%
img_idx = 1

# %%
matplotlib_imshow(test_dataset[img_idx][0])

# %%
test_dataset[img_idx][0].shape
# Out:
# torch.Size([3, 224, 224])

# %%
curr_path = os.path.abspath(os.getcwd())
img_loc = path.join(test_dataset.main_dir, test_dataset.all_images_label_map[img_idx], test_dataset.all_images[img_idx])
print(img_loc)
Image.open(img_loc).convert('RGB')
# Out:
# C:\Users\HFD347\develp\Datasets\Animals-10\cane\OIP---A27bIBcUgX1qkbpZOPswHaFS.jpeg
# <PIL.Image.Image image mode=RGB size=300x214 at 0x241A7932250>

# %%
transforms.Normalize((0.5,), (0.5,))(transforms.ToTensor()(Image.open(img_loc).convert("RGB")))
# Out:
# tensor([[[ 0.9922,  0.9922,  0.9922,  ...,  0.9765,  0.9765,  0.9843],
#          [ 0.9922,  0.9922,  0.9922,  ...,  0.9765,  0.9765,  0.9843],
#          [ 0.9922,  0.9922,  0.9922,  ...,  0.9765,  0.9765,  0.9843],
#          ...,
#          [-0.5843, -0.6000, -0.6157,  ..., -0.6314, -0.6157, -0.6078],
#          [-0.5608, -0.5922, -0.6157,  ..., -0.6157, -0.5922, -0.5686],
#          [-0.5451, -0.5843, -0.6235,  ..., -0.5843, -0.5529, -0.5137]],
#
#         [[ 0.9922,  0.9922,  0.9922,  ...,  0.9765,  0.9765,  0.9843],
#          [ 0.9922,  0.9922,  0.9922,  ...,  0.9765,  0.9765,  0.9843],
#          [ 0.9922,  0.9922,  0.9922,  ...,  0.9765,  0.9765,  0.9843],
#          ...,
#          [-0.5843, -0.6000, -0.6157,  ..., -0.6314, -0.6157, -0.6078],
#          [-0.5608, -0.5922, -0.6157,  ..., -0.6157, -0.5922, -0.5686],
#          [-0.5451, -0.5843, -0.6235,  ..., -0.5843, -0.5529, -0.5137]],
#
#         [[ 0.9922,  0.9922,  0.9922,  ...,  0.9765,  0.9765,  0.9843],
# ...

# %%
transforms.ToTensor()(Image.open(img_loc).convert("RGB"))
# Out:
# tensor([[[0.9961, 0.9961, 0.9961,  ..., 0.9882, 0.9882, 0.9922],
#          [0.9961, 0.9961, 0.9961,  ..., 0.9882, 0.9882, 0.9922],
#          [0.9961, 0.9961, 0.9961,  ..., 0.9882, 0.9882, 0.9922],
#          ...,
#          [0.2078, 0.2000, 0.1922,  ..., 0.1843, 0.1922, 0.1961],
#          [0.2196, 0.2039, 0.1922,  ..., 0.1922, 0.2039, 0.2157],
#          [0.2275, 0.2078, 0.1882,  ..., 0.2078, 0.2235, 0.2431]],
#
#         [[0.9961, 0.9961, 0.9961,  ..., 0.9882, 0.9882, 0.9922],
#          [0.9961, 0.9961, 0.9961,  ..., 0.9882, 0.9882, 0.9922],
#          [0.9961, 0.9961, 0.9961,  ..., 0.9882, 0.9882, 0.9922],
#          ...,
#          [0.2078, 0.2000, 0.1922,  ..., 0.1843, 0.1922, 0.1961],
#          [0.2196, 0.2039, 0.1922,  ..., 0.1922, 0.2039, 0.2157],
#          [0.2275, 0.2078, 0.1882,  ..., 0.2078, 0.2235, 0.2431]],
#
#         [[0.9961, 0.9961, 0.9961,  ..., 0.9882, 0.9882, 0.9922],
#          [0.9961, 0.9961, 0.9961,  ..., 0.9882, 0.9882, 0.9922],
# ...
